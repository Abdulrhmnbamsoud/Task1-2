# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd 
df=pd.read_csv("Task (1) Dataset (2).csv")

# %%
df2=df

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df2.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df2_dropped = df2.dropna()
print(df2_dropped.isnull().sum())
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df2
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df2.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# i do drop an >400

# %%
#Educational_level               741

#Vehicle_driver_relation         579
#Driving_experience              829

#Type_of_vehicle                 950
#Owner_of_vehicle                482
#Service_year_of_vehicle        3928
#Defect_of_vehicle              4427
#Area_accident_occured           239
#Lanes_or_Medians                385
#Road_allignment                 142
#Types_of_Junction               887
#Road_surface_type               172
#Type_of_collision               155
#Work_of_casuality              3198
#Fitness_of_casuality           2635

# %% [markdown]
# df2 = df2.drop(['Educational_level'], axis=1)
# df2 = df2.drop(['Work_of_casuality'], axis=1)
# df2 = df2.drop(['Vehicle_movement'], axis=1)
# df2 = df2.drop(['Defect_of_vehicle'], axis=1)
# df2 = df2.drop(['Fitness_of_casuality'], axis=1)
# df2 = df2.drop(['Service_year_of_vehicle'], axis=1)
# df2 = df2.drop(['Types_of_Junction'], axis=1)
# df2 = df2.drop(['Type_of_vehicle'], axis=1)

# %%
most_frequent_Type_of_collision = df2['Type_of_collision'].mode()[0]

df2['Type_of_collision'] = df2['Type_of_collision'].fillna(most_frequent_Type_of_collision)

print("Missing values after handling:")
print(df2.isnull().sum())
# Out:
# Missing values after handling:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# ...

# %%
most_frequentRoad_surface_type = df2['Road_surface_type'].mode()[0]

df2['Road_surface_type'] = df2['Road_surface_type'].fillna(most_frequentRoad_surface_type)

print("Missing values after handling:")
print(df2.isnull().sum())
# Out:
# Missing values after handling:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# ...

# %%
most_frequent_TRoad_allignment = df2['Road_allignment'].mode()[0]

df2['Road_allignment'] = df2['Road_allignment'].fillna(most_frequent_TRoad_allignment)

print("Missing values after handling:")
print(df2.isnull().sum())
# Out:
# Missing values after handling:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                   0
# Types_of_Junction               887
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# ...

# %% [markdown]
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Types_of_Junction               887
# Vehicle_movement                308
# Work_of_casuality              3198
# Fitness_of_casuality           2635

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df2 = df2.drop(['Educational_level'], axis=1)

# %%
df2 = df2.drop(['Work_of_casuality'], axis=1)

# %%
df2 = df2.drop(['Vehicle_movement'], axis=1)

# %%
df2 = df2.drop(['Defect_of_vehicle'], axis=1)

# %%
df2.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                   0
# Types_of_Junction               887
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# ...

# %% [markdown]
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
#
# Area_accident_occured           239
# Lanes_or_Medians                385
# Types_of_Junction               887

# %%
df2 = df2.drop(['Fitness_of_casuality'], axis=1)

# %%
df2 = df2.drop(['Service_year_of_vehicle'], axis=1)

# %%
most_frequen_tVehicle_driver_relationt= df2['Vehicle_driver_relation'].mode()[0]

df2['Vehicle_driver_relation'] = df2['Vehicle_driver_relation'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
print(df2.isnull().sum())
# Out:
# Missing values after handling:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Vehicle_driver_relation          0
# Driving_experience             829
# Type_of_vehicle                950
# Owner_of_vehicle               482
# Area_accident_occured          239
# Lanes_or_Medians               385
# Road_allignment                  0
# Types_of_Junction              887
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# ...

# %%
most_frequen_tVehicle_driver_relationt= df2['Lanes_or_Medians'].mode()[0]

df2['Lanes_or_Medians'] = df2['Lanes_or_Medians'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
print(df2.isnull().sum())
# Out:
# Missing values after handling:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Vehicle_driver_relation          0
# Driving_experience             829
# Type_of_vehicle                950
# Owner_of_vehicle               482
# Area_accident_occured          239
# Lanes_or_Medians                 0
# Road_allignment                  0
# Types_of_Junction              887
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# ...

# %%
df2
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                    Employee              1-2yr           Automobile
# 1                    Employee         Above 10yr  Public (> 45 seats)
# ...

# %%
df2 = df2.drop(['Types_of_Junction'], axis=1)

# %%
df2 = df2.drop(['Type_of_vehicle'], axis=1)

# %%
print(df2.isnull().sum())
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Vehicle_driver_relation          0
# Driving_experience             829
# Owner_of_vehicle               482
# Area_accident_occured          239
# Lanes_or_Medians                 0
# Road_allignment                  0
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# dtype: int64

# %%
most_frequen_tVehicle_driver_relationt= df2['Area_accident_occured'].mode()[0]

df2['Area_accident_occured'] = df2['Area_accident_occured'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
print(df2.isnull().sum())
# Out:
# Missing values after handling:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Vehicle_driver_relation          0
# Driving_experience             829
# Owner_of_vehicle               482
# Area_accident_occured            0
# Lanes_or_Medians                 0
# Road_allignment                  0
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# dtype: int64

# %%
most_frequen_tVehicle_driver_relationt= df2['Driving_experience'].mode()[0]

df2['Driving_experience'] = df2['Driving_experience'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
print(df2.isnull().sum())
# Out:
# Missing values after handling:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Vehicle_driver_relation          0
# Driving_experience               0
# Owner_of_vehicle               482
# Area_accident_occured            0
# Lanes_or_Medians                 0
# Road_allignment                  0
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# dtype: int64

# %%
most_frequen_tVehicle_driver_relationt= df2['Owner_of_vehicle'].mode()[0]

df2['Owner_of_vehicle'] = df2['Owner_of_vehicle'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
print(df2.isnull().sum())
# Out:
# Missing values after handling:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Vehicle_driver_relation        0
# Driving_experience             0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Vehicle_driver_relation      12316 non-null  object
#  5   Driving_experience           12316 non-null  object
#  6   Owner_of_vehicle             12316 non-null  object
#  7   Area_accident_occured        12316 non-null  object
#  8   Lanes_or_Medians             12316 non-null  object
#  9   Road_allignment              12316 non-null  object
#  10  Road_surface_type            12316 non-null  object
#  11  Road_surface_conditions      12316 non-null  object
#  12  Light_conditions             12316 non-null  object
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df2.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0  17:02:00      Monday              18-30          Male
# 1  17:02:00      Monday              31-50          Male
# 2  17:02:00      Monday              18-30          Male
# 3   1:06:00      Sunday              18-30          Male
# 4   1:06:00      Sunday              18-30          Male
#
#   Vehicle_driver_relation Driving_experience Owner_of_vehicle  \
# 0                Employee              1-2yr            Owner
# 1                Employee         Above 10yr            Owner
# 2                Employee              1-2yr            Owner
# 3                Employee             5-10yr     Governmental
# 4                Employee              2-5yr            Owner
#
#   Area_accident_occured                                  Lanes_or_Medians  \
# 0     Residential areas  Two-way (divided with broken lines road marking)
# 1          Office areas                                 Undivided Two way
# ...

# %% [markdown]
# Casualty_class	Casualty_class Age_band_of_casualty	 Age_band_of_casualty

# %%
most_frequen_tVehicle_driver_relationt= df2['Casualty_class'].mode()[0]

df2['Casualty_class'] = df2['Casualty_class'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
# Out:
# Missing values after handling:

# %%
most_frequen_tVehicle_driver_relationt= df2['Sex_of_casualty'].mode()[0]

df2['Sex_of_casualty'] = df2['Sex_of_casualty'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
# Out:
# Missing values after handling:

# %%
most_frequen_tVehicle_driver_relationt= df2['Age_band_of_casualty'].mode()[0]

df2['Age_band_of_casualty'] = df2['Age_band_of_casualty'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
# Out:
# Missing values after handling:

# %%
most_frequen_tVehicle_driver_relationt= df2['Casualty_severity'].mode()[0]

df2['Casualty_severity'] = df2['Casualty_severity'].fillna(most_frequen_tVehicle_driver_relationt)

print("Missing values after handling:")
# Out:
# Missing values after handling:

# %%
df2 = df2.drop(['Casualty_class'], axis=1)
df2 = df2.drop(['Sex_of_casualty'], axis=1)
df2 = df2.drop(['Age_band_of_casualty'], axis=1)
df2 = df2.drop(['Casualty_severity'], axis=1)

# %%
df2
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Vehicle_driver_relation Driving_experience Owner_of_vehicle  \
# 0                    Employee              1-2yr            Owner
# 1                    Employee         Above 10yr            Owner
# ...

# %%
df2.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Vehicle_driver_relation        0
# Driving_experience             0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df2
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Vehicle_driver_relation Driving_experience Owner_of_vehicle  \
# 0                    Employee              1-2yr            Owner
# 1                    Employee         Above 10yr            Owner
# ...

# %%
df2.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df2
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Vehicle_driver_relation Driving_experience Owner_of_vehicle  \
# 0                    Employee              1-2yr            Owner
# 1                    Employee         Above 10yr            Owner
# ...

# %%
grouped_data=df2.groupby("Day_of_week").agg(
    Number_of_vehicles_involved=("Number_of_vehicles_involved","count"),
    Number_of_casualties=("Number_of_casualties","mean")
    
)
grouped_data
# Out:
#              Number_of_vehicles_involved  Number_of_casualties
# Day_of_week
# Friday                              2041              1.540421
# Monday                              1681              1.529447
# Saturday                            1666              1.648259
# Sunday                              1467              1.844581
# Thursday                            1851              1.470016
# Tuesday                             1770              1.462147
# Wednesday                           1840              1.408152

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df2
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Vehicle_driver_relation Driving_experience Owner_of_vehicle  \
# 0                    Employee              1-2yr            Owner
# 1                    Employee         Above 10yr            Owner
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Vehicle_driver_relation      12316 non-null  object
#  5   Driving_experience           12316 non-null  object
#  6   Owner_of_vehicle             12316 non-null  object
#  7   Area_accident_occured        12316 non-null  object
#  8   Lanes_or_Medians             12316 non-null  object
#  9   Road_allignment              12316 non-null  object
#  10  Road_surface_type            12316 non-null  object
#  11  Road_surface_conditions      12316 non-null  object
#  12  Light_conditions             12316 non-null  object
# ...

# %%
df2 =df2[['Number_of_vehicles_involved','Number_of_casualties']]
corr=df2.corr()
print(corr)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.subplots(figsize=(11, 9))
sns.heatmap(corr,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.pairplot(df2)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

plt.subplots(figsize=(11, 9))
sns.barplot(x='Number_of_vehicles_involved', y='Number_of_casualties', data=df2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=df2, x='Number_of_vehicles_involved', y='Number_of_casualties')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.pairplot(df)

# %%
df2
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# 0                                2                     2
# 1                                2                     2
# 2                                2                     2
# 3                                2                     2
# 4                                2                     2
# ...                            ...                   ...
# 12311                            2                     1
# 12312                            2                     1
# 12313                            1                     1
# 12314                            2                     1
# 12315                            2                     1
#
# [12316 rows x 2 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Number_of_vehicles_involved  12316 non-null  int64
#  1   Number_of_casualties         12316 non-null  int64
# dtypes: int64(2)
# memory usage: 192.6 KB

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
import pandas as pd 
plt.figure(figsize=(5,5))
sns.histplot(df2)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd 
plt.figure(figsize=(5,5))
sns.jointplot(df2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.subplots(figsize=(11, 9))
sns.heatmap(corr,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
df2
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# 0                                2                     2
# 1                                2                     2
# 2                                2                     2
# 3                                2                     2
# 4                                2                     2
# ...                            ...                   ...
# 12311                            2                     1
# 12312                            2                     1
# 12313                            1                     1
# 12314                            2                     1
# 12315                            2                     1
#
# [12316 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#  Ensure that the 'Number_of_vehicles_involved' column contains only numeric values
df= pd.read_csv('Task (2) Dataset.csv')

# Extract only the numeric columns of the correlation matrix
df['TrafficIndexLive'] = pd.to_numeric(df['TrafficIndexLive'], errors='coerce')

# Create a numeric-only correlation matrix
numeric_df = df2.select_dtypes(include=['float64', 'int64'])

# Create a numeric-only correlation matrix
corr = numeric_df.corr()

fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# 1. Scatter Plot
sns.scatterplot(df, ax=axes[0, 0])
axes[0, 0].set_title('TrafficIndexWeekAgo')

# 2. displot Chart
axes[0, 1]
sns.displot(
    df,
    x="TrafficIndexLive", hue="TrafficIndexWeekAgo",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)
axes[0, 1].set_title('TrafficIndexWeekAgo')

sns.jointplot(df,x='TrafficIndexLive', y='TrafficIndexWeekAgo')
axes[1, 0].set_title('TrafficIndexWeekAgo')

# 3. Bar Plot
sns.barplot(x='City', y='TrafficIndexWeekAgo',data=df, ax=axes[1, 0]) 

axes[1, 0].set_title('TrafficIndexWeekAgo')

# 4. Heatmap
sns.heatmap(corr, annot=True, ax=axes[1, 1]) 
axes[1, 1].set_title('TrafficIndexWeekAgo Heatmap')

# Adjust spacing between graphs
plt.tight_layout()

plt.show()
# Out:
# C:\Users\abdau\AppData\Local\Temp\ipykernel_19196\3130302704.py:25: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(

# %% [markdown]
# This is all data before deletion or modification
# #Educational_level               741
#
# #Vehicle_driver_relation         579
# #Driving_experience              829
#
# #Type_of_vehicle                 950
# #Owner_of_vehicle                482
# #Service_year_of_vehicle        3928
# #Defect_of_vehicle              4427
# #Area_accident_occured           239
# #Lanes_or_Medians                385
# #Road_allignment                 142
# #Types_of_Junction               887
# #Road_surface_type               172
# #Type_of_collision               155
# #Work_of_casuality              3198
# #Fitness_of_casuality           2635

# %% [markdown]
# All data was deleted because the null size was too high
# df2 = df2.drop(['Casualty_class'], axis=1)
# df2 = df2.drop(['Sex_of_casualty'], axis=1)
# df2 = df2.drop(['Age_band_of_casualty'], axis=1)
# df2 = df2.drop(['Casualty_severity'], axis=1)

# %% [markdown]
# After cleaning the data, the number of data became 25 out of 32

# %% [markdown]
# In conclusion, I noticed a strong relationship between...
# Number_of_vehicles_involved Number_of_casualties
